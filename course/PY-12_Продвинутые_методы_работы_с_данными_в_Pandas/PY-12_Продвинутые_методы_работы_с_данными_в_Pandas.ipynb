# %% [markdown]
# # 1. Введение

# %% [markdown]
# ### ВСПОМНИМ, С КАКИМИ ДАННЫМИ МЫ РАБОТАЕМ

# %%
import pandas as pd

# %%
melb_df = pd.read_csv('./data/melb_data_fe.csv')
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])j
# Out:
#   File "/var/folders/0l/7c83kg195b71n7hk073bcznr0000gn/T/ipykernel_2052/44611213.py", line 1
#     melb_df['Date'] = pd.to_datetime(melb_df['Date'])j
#                                                      ^
# SyntaxError: invalid syntax

# %%
melb_df['Date'].dt.quarter.value_counts()
# Out:
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: Date, dtype: int64

# %%
unique_list = []

for col in melb_df.columns:
    item = (col, melb_df[col].nunique(), melb_df[col].dtype)
    unique_list.append(item)
    
unique_counts = pd.DataFrame(
    data=unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique', ignore_index=True ,ascending=True)

unique_counts
# Out:
#         Column_Name  Num_Unique            Type
# 0           Weekend           2           int64
# 1              Type           3          object
# 2            Method           5          object
# 3       WeekdaySale           7           int64
# 4        Regionname           8          object
# 5             Rooms           9           int64
# 6          Bathroom           9           int64
# 7               Car          11           int64
# 8        StreetType          11          object
# 9         MonthSale          12           int64
# 10          Bedroom          12           int64
# 11      CouncilArea          33          object
# 12          SellerG          50          object
# 13             Date          58  datetime64[ns]
# 14           Suburb         120          object
# 15      AgeBuilding         152           int64
# 16         Postcode         198           int64
# 17         Distance         202         float64
# 18    Propertycount         311           int64
# ...

# %%
exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_unique_count = 150
count = 0
for col in melb_df.columns:
    if melb_df[col].nunique() > max_unique_count:
        continue
    if col in exclude:
        continue
    melb_df[col] = melb_df[col].astype('category')
    count += 1

print(count)
display(melb_df.info())
# Out:
# 10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %% [markdown]
# # 2. Сортировка данных в DataFrame

# %% [markdown]
# ### СОРТИРОВКА ПО ЗНАЧЕНИЯМ ОДНОГО СТОЛБЦА

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %% [markdown]
# ### СОРТИРОВКА ПО ЗНАЧЕНИЯМ НЕСКОЛЬКИХ СТОЛБЦОВ

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %% [markdown]
# ### КОМБИНИРОВАНИЕ СОРТИРОВКИ С ФИЛЬТРАЦИЕЙ

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %% [markdown]
# ### Задачи

# %%
melb_df.sort_values(by='AreaRatio', ascending=False, ignore_index=True)['BuildingArea'].iloc[1558]
# Out:
# 126.0

# %%
mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2
melb_df[mask1 & mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Rooms', 'MeanRoomsSquare', 'Price']].iloc[18]
# Out:
# Rooms                    3.00
# MeanRoomsSquare         27.75
# Price              1300000.00
# Name: 18, dtype: float64

# %% [markdown]
# # 3. Группировка данных в DataFrame

# %% [markdown]
# ### МЕТОД GROUPBY()

# %% [markdown]
# Метод groupby() возвращает объект DataFrameGroupBy, который хранит в себе информацию о том, какие строки относятся к определённой группе, и сам по себе не представляет для нас интереса.
#
# Однако к этому объекту можно применять уже знакомые нам агрегирующие методы (mean, median, sum и т. д.), чтобы рассчитывать показатели внутри каждой группы.

# %% [markdown]
# #### ГРУППИРОВКА ДАННЫХ ПО ОДНОМУ КРИТЕРИЮ С ОДНОЙ АГРЕГАЦИЕЙ

# %%
melb_df.groupby(by='Type').mean()
# Out:
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
#            Propertycount  MeanRoomsSquare  AreaRatio  AgeBuilding
# Type
# house        7259.025505        18.996731  -0.490031    55.669700
# townhouse    7094.459605        18.569847  -0.094916    26.690305
# unit         8199.280080        21.068242   0.319883    39.703016

# %%
melb_df.groupby(by='Type', as_index=False).mean()
# Out:
#         Type     Rooms         Price   Distance     Postcode   Bedroom  \
# 0      house  3.260874  1.242665e+06  10.979479  3104.080643  3.229336
# 1  townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183
# 2       unit  1.963871  6.051275e+05   7.607391  3110.797481  1.966523
#
#    Bathroom       Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# 0  1.613822  1.772674  617.181924    152.162553 -37.803795  144.994700
# 1  1.809695  1.555655  279.606822    134.649710 -37.815782  144.996489
# 2  1.183295  1.128936  477.314219    102.235863 -37.823710  144.996363
#
#    Propertycount  MeanRoomsSquare  AreaRatio  AgeBuilding
# 0    7259.025505        18.996731  -0.490031    55.669700
# 1    7094.459605        18.569847  -0.094916    26.690305
# 2    8199.280080        21.068242   0.319883    39.703016

# %%
melb_df.groupby(by='Type')['Price'].mean()
# Out:
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %% [markdown]
# #### ГРУППИРОВКА ДАННЫХ ПО ОДНОМУ КРИТЕРИЮ С НЕСКОЛЬКИМИ АГРЕГАЦИЯМИ

# %%
melb_df.groupby(by='MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
melb_df.groupby(by='MonthSale')['Price'].agg(
    'describe'
).sort_values(by='count', ascending=False)
# Out:
#             count          mean            std       min       25%        50%  \
# MonthSale
# 8          1850.0  1.056371e+06  619617.476541  160000.0  635000.0   892000.0
# 7          1835.0  9.314698e+05  537390.803161  190000.0  586750.0   800000.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 9          1188.0  1.126349e+06  608734.690742  170000.0  725000.0   980000.0
# 10          854.0  1.135970e+06  692950.251627  250000.0  652625.0   950000.0
# 11          750.0  1.142503e+06  703666.227892  240000.0  671750.0   950000.0
# 12          725.0  1.144737e+06  706549.007161  250000.0  667500.0   938000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# ...

# %%
melb_df.groupby('Regionname')['SellerG'].agg(
    ['nunique', set]
)
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Noel, RT, Woodards, Marshall, Nelson, Biggin,...
# Eastern Victoria            {Eview, McGrath, hockingstuart, Barry, C21, HA...
# Northern Metropolitan       {Raine, Biggin, Woodards, Marshall, Nelson, RT...
# Northern Victoria           {Buckingham, Raine, McGrath, hockingstuart, LI...
# South-Eastern Metropolitan  {Noel, Biggin, Woodards, Nelson, other, Buxton...
# Southern Metropolitan       {Raine, Noel, RT, Biggin, Marshall, Woodards, ...
# ...

# %%
df = melb_df.groupby('Regionname')['SellerG'].agg(
    ['nunique', set]
)
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 8 entries, Eastern Metropolitan to Western Victoria
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nunique  8 non-null      int64
#  1   set      8 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 500.0+ bytes
#          nunique
# count   8.000000
# mean   23.875000
# std    13.195643
# min     6.000000
# 25%    11.000000
# 50%    25.500000
# 75%    35.000000
# max    40.000000

# %% [markdown]
# ### Задачи

# %%
df = melb_df.groupby(['Rooms'], as_index=False)['Price'].mean()
df.sort_values(by='Price', ascending=False)
# Out:
#    Rooms         Price
# 6      7  1.920700e+06
# 4      5  1.870260e+06
# 5      6  1.849366e+06
# 7      8  1.602750e+06
# 3      4  1.445282e+06
# 2      3  1.076081e+06
# 8     10  9.000000e+05
# 1      2  7.750812e+05
# 0      1  4.338245e+05

# %%
melb_df.groupby('Regionname')['Lattitude'].std()
# Out:
# Regionname
# Eastern Metropolitan          0.047890
# Eastern Victoria              0.147067
# Northern Metropolitan         0.049639
# Northern Victoria             0.084455
# South-Eastern Metropolitan    0.073411
# Southern Metropolitan         0.043080
# Western Metropolitan          0.051251
# Western Victoria              0.011579
# Name: Lattitude, dtype: float64

# %%
mask = (melb_df['Date'] >= '2017-05-01') & (melb_df['Date'] <= '2017-09-01')
melb_df[mask].groupby('SellerG', as_index=False)['Price'].sum().sort_values('Price', ascending=True)
# Out:
#           SellerG        Price
# 23         LITTLE    2742000.0
# 9          Cayzer    4439000.0
# 6         Burnham    4550500.0
# 29         Moonee    7328000.0
# 43        Thomson    8332000.0
# 2           Bells    8656000.0
# 0      Alexkarbon   10985000.0
# 26       McDonald   14637500.0
# 40        Rendina   15422276.0
# 31           Nick   16890000.0
# 12        Douglas   18341000.0
# 5      Buckingham   19033000.0
# 8             C21   19515000.0
# 13          Eview   19791500.0
# 11        Collins   20217000.0
# 34         Philip   22051800.0
# 10       Chisholm   23225000.0
# 45       Williams   23297000.0
# 24           Love   23365500.0
# 35   Purplebricks   23401000.0
# 33        O'Brien   23855508.0
# 17            HAR   25568000.0
# 44        Village   26473000.0
# 37             RW   29261000.0
# 38          Raine   30687700.0
# 41      Stockdale   35409800.0
# 42        Sweeney   36882750.0
# 15           Gary   39138400.0
# 19         Hodges   43231000.0
# ...

# %% [markdown]
# # 4. Сводные таблицы

# %%
melb_df.groupby('Rooms')[['Price', 'BuildingArea']].median()
# Out:
#            Price  BuildingArea
# Rooms
# 1       385000.0         107.0
# 2       690000.0         126.0
# 3       950000.0         126.0
# 4      1285000.0         142.0
# 5      1660000.0         176.0
# 6      1800000.0         126.0
# 7      1496000.0         216.5
# 8      1515000.0         126.0
# 10      900000.0         126.0

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Out:
# Rooms  Type
# 1      house        8.668655e+05
#        townhouse    5.927045e+05
#        unit         3.899289e+05
# 2      house        1.017238e+06
#        townhouse    7.101585e+05
#        unit         6.104905e+05
# 3      house        1.109233e+06
#        townhouse    9.847087e+05
#        unit         8.505963e+05
# 4      house        1.462283e+06
#        townhouse    1.217092e+06
#        unit         1.037476e+06
# 5      house        1.877327e+06
#        townhouse    1.035000e+06
#        unit                  NaN
# 6      house        1.869508e+06
#        townhouse             NaN
#        unit         5.200000e+05
# 7      house        1.920700e+06
#        townhouse             NaN
#        unit                  NaN
# 8      house        1.510286e+06
#        townhouse             NaN
#        unit         2.250000e+06
# 10     house        9.000000e+05
#        townhouse             NaN
#        unit                  NaN
# Name: Price, dtype: float64

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# Type          house     townhouse          unit
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
melb_df.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0,
).round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)
# Out:
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean']
).round()
# Out:
#                            median                     mean
# Type                        house townhouse   unit   house townhouse   unit
# Regionname
# Eastern Metropolitan        674.0     234.0  203.0   717.0     269.0  330.0
# Eastern Victoria            843.0       NaN  230.0  3109.0       NaN  295.0
# Northern Metropolitan       460.0     134.0    0.0   619.0     317.0  495.0
# Northern Victoria           724.0       NaN    NaN  3355.0       NaN    NaN
# South-Eastern Metropolitan  630.0     240.0  199.0   664.0     212.0  358.0
# Southern Metropolitan       586.0     246.0    0.0   570.0     279.0  466.0
# Western Metropolitan        531.0     198.0   62.0   508.0     245.0  558.0
# Western Victoria            600.0       NaN    NaN   656.0       NaN    NaN

# %% [markdown]
# ### МНОГОМЕРНЫЕ СВОДНЫЕ ТАБЛИЦЫ

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method', 'Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                   1244000            780000
#        townhouse                760000                 0
#        unit                     650000                 0
# S      house                   1127000            675000
#        townhouse                828000                 0
#        unit                     645750            492000
# SA     house                    932500            950000
#        townhouse                807500                 0
#        unit                          0                 0
# SP     house                   1050000            672500
#        townhouse                910000                 0
#        unit                     515000            400000
# VB     house                   1100000            712500
#        townhouse                892500                 0
#        unit                     500000                 0
#
# ...

# %% [markdown]
# ### ДОСТУП К ДАННЫМ В СВОДНОЙ ТАБЛИЦЕ

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
pivot['mean']['unit']
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: unit, dtype: float64

# %%
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
filtered_pivot
# Out:
#                       median                       mean              \
# Type                   house townhouse unit       house   townhouse
# Regionname
# Southern Metropolitan  586.0     246.0    0  569.643881  278.858824
# Western Metropolitan   531.0     198.0   62  507.883406  244.560669
#
#
# Type                         unit
# Regionname
# Southern Metropolitan  466.380245
# Western Metropolitan   557.637232

# %%
list(filtered_pivot.index)
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
import numpy as np
np.random.seed(10)
mser = pd.Series(
    np.random.rand(8),
	index=[['white','white','white','blue','blue','red','red','red'], 
           ['up','down','right','up','down','up','down','left']])
display(mser)
# Out:
# white  up       0.771321
#        down     0.020752
#        right    0.633648
# blue   up       0.748804
#        down     0.498507
# red    up       0.224797
#        down     0.198063
#        left     0.760531
# dtype: float64

# %%
print(mser.index)
# Out:
# MultiIndex([('white',    'up'),
#             ('white',  'down'),
#             ('white', 'right'),
#             ( 'blue',    'up'),
#             ( 'blue',  'down'),
#             (  'red',    'up'),
#             (  'red',  'down'),
#             (  'red',  'left')],
#            )

# %%
mframe = pd.DataFrame(
    np.random.randn(16).reshape(4,4),
    index=[['white','white','red','red'], ['up','down','up','down']],
    columns=[['pen','pen','paper','paper'],[1,2,1,2]]
)
display(mframe)
# Out:
#                  pen               paper
#                    1         2         1         2
# white up    0.265512  0.108549  0.004291 -0.174600
#       down  0.433026  1.203037 -0.965066  1.028274
# red   up    0.228630  0.445138 -1.136602  0.135137
#       down  1.484537 -1.079805 -1.977728 -1.743372

# %% [markdown]
# ### Задачи

# %%
melb_df.pivot_table(
    values='BuildingArea',
    index='Rooms',
    columns='Type',
    aggfunc='median'
)
# Out:
# Type   house  townhouse   unit
# Rooms
# 1      126.0       88.0   69.5
# 2      126.0      114.0  110.0
# 3      126.0      126.0  126.0
# 4      141.0      159.5  126.0
# 5      177.0      152.0    NaN
# 6      126.0        NaN  171.0
# 7      216.5        NaN    NaN
# 8      126.0        NaN  126.0
# 10     126.0        NaN    NaN

# %%
melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc='mean'
).sort_values(by='unit', ascending=False)
# Out:
# Type                  house     townhouse           unit
# SellerG
# Nick           2.111984e+06  7.800000e+05  993642.857143
# Kay            2.471453e+06  1.648818e+06  851660.606061
# Cayzer         1.608258e+06  1.277333e+06  832333.333333
# Marshall       2.161028e+06  1.590250e+06  770044.678261
# Philip         1.068569e+06  7.370000e+05  706255.555556
# RT             1.841567e+06  1.261643e+06  703509.803922
# C21            9.693400e+05  7.687500e+05  700700.000000
# Fletchers      1.480143e+06  1.248796e+06  691625.000000
# Williams       1.258358e+06  8.587143e+05  685386.486486
# Noel           1.453143e+06  1.126570e+06  678085.714286
# Hodges         1.628754e+06  1.184559e+06  677227.272727
# Buxton         1.439187e+06  1.138067e+06  664625.954198
# Jellis         1.657952e+06  1.108469e+06  662828.060897
# Chisholm       1.543138e+06  1.056000e+06  658447.651163
# Moonee         8.194677e+05  7.150000e+05  649000.000000
# ...

# %% [markdown]
# # 5. Объединение DataFrame: знакомимся с новыми данными

# %%
dates = pd.read_csv('./data/movies_data/dates.csv')
ratings1 = pd.read_csv('./data/movies_data/ratings1.csv')
ratings2 = pd.read_csv('./data/movies_data/ratings2.csv')
movies = pd.read_csv('./data/movies_data/movies.csv')

# %%
ratings1.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies['movieId'].nunique()
# Out:
# 9742

# %%
ratings1['userId'].nunique()
# Out:
# 274

# %%
pd.to_datetime(dates['date']).dt.year.value_counts()
# Out:
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: date, dtype: int64

# %% [markdown]
# # 6. Объединение DataFrame: concat

# %%
ratings = pd.concat([ratings1, ratings2], ignore_index=True)
ratings
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице dates: ', dates.shape[0])
print(ratings.shape[0] == dates.shape[0])
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице dates:  100836
# False

# %%
ratings.drop_duplicates(ignore_index=True, inplace=True)

# %%
ratings.shape[0]
# Out:
# 100836

# %%
ratings_dates = pd.concat([ratings, dates], axis=1)
ratings_dates.tail(7)
# Out:
#         userId  movieId  rating                 date
# 100829     610   164179     5.0  2017-05-03 21:07:11
# 100830     610   166528     4.0  2017-05-04 06:29:25
# 100831     610   166534     4.0  2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15

# %% [markdown]
# # 7. Объединение DataFrame: join, merge

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ### МЕТОД ОБЪЕДИНЕНИЯ JOIN

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
joined_false
# Out:
#         userId  movieId  rating                 date  movieId_right  \
# 0            1        1     4.0  2000-07-30 18:45:03            1.0
# 1            1        3     4.0  2000-07-30 18:20:47            2.0
# 2            1        6     4.0  2000-07-30 18:37:04            3.0
# 3            1       47     5.0  2000-07-30 19:03:35            4.0
# 4            1       50     5.0  2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                  ...            ...
# 100831     610   166534     4.0  2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0  2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0  2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0  2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0  2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
joined_false
# Out:
#         userId  movieId  rating                 date  \
# 0            1        1     4.0  2000-07-30 18:45:03
# 1            1        3     4.0  2000-07-30 18:20:47
# 2            1        6     4.0  2000-07-30 18:37:04
# 3            1       47     5.0  2000-07-30 19:03:35
# 4            1       50     5.0  2000-07-30 18:48:51
# ...        ...      ...     ...                  ...
# 100831     610   166534     4.0  2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100831                    Split (2017)
# ...

# %% [markdown]
# ### МЕТОД ОБЪЕДИНЕНИЯ MERGE

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                 date                        title  \
# 0       1        1     4.0  2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0  2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0  2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0  2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
print('Число строк в таблице ratings_dates: ', ratings_dates.shape[0])
print('Число строк в таблице merged: ', merged.shape[0])
print(ratings_dates.shape[0] == merged.shape[0])
# Out:
# Число строк в таблице ratings_dates:  100836
# Число строк в таблице merged:  100836
# True

# %% [markdown]
# #### ОСОБЕННОСТИ ИСПОЛЬЗОВАНИЯ MERGE()

# %%
merged2 = ratings_dates.merge(
    movies,
    on='movieId',
    how='outer'
)
print('Число строк в таблице merged2: ', merged2.shape[0])
display(merged2.tail())
# Out:
# Число строк в таблице merged2:  100854
#         userId  movieId  rating date                               title  \
# 100849     NaN    30892     NaN  NaN  In the Realms of the Unreal (2004)
# 100850     NaN    32160     NaN  NaN            Twentieth Century (1934)
# 100851     NaN    32371     NaN  NaN           Call Northside 777 (1948)
# 100852     NaN    34482     NaN  NaN        Browning Version, The (1951)
# 100853     NaN    85565     NaN  NaN                  Chalet Girl (2011)
#
#                        genres
# 100849  Animation|Documentary
# 100850                 Comedy
# 100851  Crime|Drama|Film-Noir
# 100852                  Drama
# 100853         Comedy|Romance

# %%
merge_ratings = ratings1.merge(ratings2, how='outer')
merge_ratings
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %% [markdown]
# *merge* - *автоматически удаляет дубликаты*

# %% [markdown]
# ### Задачи

# %%
items_df = pd.DataFrame({
'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 
'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
})

purchase_df = pd.DataFrame({
    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 
    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
})

# %%
purchase_df
# Out:
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400

# %%
items_df
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19

# %%
merged = purchase_df.merge(items_df, on='item_id', how='inner')
merged
# Out:
#    purchase_id  item_id  price   vendor  stock_count
# 0          101   417283  13900  Samsung           54
# 1          101   849734   5330       LG           33
# 2          101   132223  38200    Apple          122
# 3          112   573943  49990    Apple           18
# 4          121    19475   9890       LG          102
# 5          145  3294095  33000    Apple           43
# 6          145   382043  67500  Samsung           77
# 7          145   302948  34500  Samsung          143
# 8          221   100132  11400       LG           60

# %%
merged['total'] = merged['price'] * merged['stock_count']

# %%
income = merged['total'].sum()
income
# Out:
# 19729490

# %% [markdown]
# # 8. Закрепление знаний

# %%
ratings_movies = pd.read_csv('./data/ratings_movies.csv')
ratings_movies.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
ratings_movies['year_release'] = ratings_movies['title'].apply(get_year_release)
ratings_movies.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres  \
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller
#
#    year_release
# 0        1995.0
# 1        1995.0
# 2        1995.0
# 3        1995.0
# 4        1995.0

# %%
ratings_movies[ratings_movies['year_release'].isna()].shape
# Out:
# (18, 8)

# %%
ratings_movies[ratings_movies['year_release']==1999].groupby('title')['rating'].mean().sort_values()
# Out:
# title
# Bloodsport: The Dark Kumite (1999)            0.5
# Simon Sez (1999)                              1.0
# Chill Factor (1999)                           1.0
# Source, The (1999)                            1.0
# Trippin' (1999)                               1.0
#                                              ...
# Trailer Park Boys (1999)                      5.0
# Larry David: Curb Your Enthusiasm (1999)      5.0
# Sun Alley (Sonnenallee) (1999)                5.0
# George Carlin: You Are All Diseased (1999)    5.0
# Five Senses, The (1999)                       5.0
# Name: rating, Length: 261, dtype: float64

# %%
ratings_movies[ratings_movies['year_release']==2010].groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %%
ratings_movies.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
ratings_movies.groupby('userId')['rating'].agg(['count', 'mean']).sort_values(['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
t = ratings_movies[ratings_movies['year_release']==2018].groupby('genres')['rating'].agg(['mean', 'count'])
t[t['count']>10].sort_values('mean', ascending=False)
# Out:
#                              mean  count
# genres
# Action|Adventure|Sci-Fi  3.928571     14
# Action|Comedy|Sci-Fi     3.875000     12

# %%
ratings_movies['year_rating'] = pd.to_datetime(ratings_movies['date']).dt.year
ratings_movies.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres  \
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller
#
#    year_release  year_rating
# 0        1995.0         2000
# 1        1995.0         2000
# 2        1995.0         2000
# ...

# %%
pt = ratings_movies.pivot_table(
    values='rating',
    index='year_rating',
    columns='genres',
    aggfunc='mean'
)
pt
# Out:
# genres       (no genres listed)    Action  Action|Adventure  \
# year_rating
# 1996                        NaN  2.730769          3.454545
# 1997                        NaN  3.538462          4.150000
# 1998                        NaN       NaN          4.200000
# 1999                        NaN       NaN          4.000000
# 2000                        NaN  2.588235          3.738462
# 2001                        NaN  3.000000          3.500000
# 2002                        NaN  2.750000          4.304348
# 2003                        NaN  3.833333          3.277778
# 2004                        NaN  2.700000          4.136364
# 2005                        NaN  3.357143          3.413043
# 2006                        NaN  2.166667          4.090909
# 2007                        NaN  2.583333          3.666667
# 2008                        NaN  3.000000          3.656250
# 2009                        NaN       NaN          3.714286
# ...

# %%
pt['Action|Adventure|Animation|Children|Comedy|IMAX'].sort_values(ascending=False)
# Out:
# year_rating
# 2013    5.000000
# 2018    3.700000
# 2016    3.666667
# 2012    3.550000
# 2010    3.500000
# 2014    3.500000
# 2015    3.375000
# 2009    3.250000
# 2017    1.000000
# 1996         NaN
# 1997         NaN
# 1998         NaN
# 1999         NaN
# 2000         NaN
# 2001         NaN
# 2002         NaN
# 2003         NaN
# 2004         NaN
# 2005         NaN
# 2006         NaN
# 2007         NaN
# 2008         NaN
# 2011         NaN
# Name: Action|Adventure|Animation|Children|Comedy|IMAX, dtype: float64

# %%
pt.loc[2018, 'Animation|Children|Mystery']
# Out:
# 5.0

# %%
pt['Comedy'].sort_values(ascending=False)
# Out:
# year_rating
# 1999    3.606061
# 2013    3.489474
# 2012    3.478477
# 2008    3.426667
# 1997    3.409091
# 2016    3.373431
# 2004    3.356877
# 2006    3.347534
# 2001    3.318408
# 2009    3.273292
# 2014    3.271429
# 2011    3.232877
# 1996    3.228571
# 2002    3.198556
# 2010    3.179825
# 2000    3.141291
# 2018    3.121296
# 2003    3.120066
# 2015    3.106183
# 1998    3.000000
# 2005    2.963325
# 2007    2.928187
# 2017    2.852668
# Name: Comedy, dtype: float64

# %%
orders = pd.read_csv('./data/orders_and_products/orders.csv')
products = pd.read_csv('./data/orders_and_products/products.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/0l/7c83kg195b71n7hk073bcznr0000gn/T/ipykernel_2052/1866689338.py in <module>
#       1 orders = pd.read_csv('./data/orders_and_products/orders.csv')
# ----> 2 products = pd.read_csv('./data/orders_and_products/products.csv')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
